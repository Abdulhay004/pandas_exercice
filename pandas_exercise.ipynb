# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulhay004/pandas_library/blob/main/pandas_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
name = ['Avery Bradley', 'John Holland', 'Jonas Jerebko', 'Jordan Mickey', 'Terry Rozier', 'Jered Sullinger', 'Evan Turner']
team = ['Boston Celtics', 'Boston Celtics', 'Boston Celtics', 'Boston Celtics', 'Boston Celtics', 'Boston Celtics', 'Boston Celtics']
number = [0.0, 30.0, 8.0, 'NaN', 12.0, 7.0, 11.0]
position = ['PG', 'SG', 'PF', 'PF', 'PG', 'C', 'SG']
age = [25.0, 27.0, 29.0, 21.0, 22.0, 'NaN', 27.0]

# %%
data = pd.DataFrame({'Name':name, 'Team':team, 'Number':number, 'Position':position, 'Age':age})

# %%
df = data.copy()

# %%
data
# Out:
#               Name            Team Number Position   Age
# 0    Avery Bradley  Boston Celtics    0.0       PG  25.0
# 1     John Holland  Boston Celtics   30.0       SG  27.0
# 2    Jonas Jerebko  Boston Celtics    8.0       PF  29.0
# 3    Jordan Mickey  Boston Celtics    NaN       PF  21.0
# 4     Terry Rozier  Boston Celtics   12.0       PG  22.0
# 5  Jered Sullinger  Boston Celtics    7.0        C   NaN
# 6      Evan Turner  Boston Celtics   11.0       SG  27.0

# %%
n = 0
for i in data.shape:
  if n == 0:
    print('rows: {}'.format(i).capitalize())
    n += 1
  else:
    print('columns: {}'.format(i).capitalize())
# Out:
# Rows: 7
# Columns: 5

# %%
transpose = data.transpose()

# %%
transpose[:]
# Out:
#                        0               1               2               3  \
# Name       Avery Bradley    John Holland   Jonas Jerebko   Jordan Mickey
# Team      Boston Celtics  Boston Celtics  Boston Celtics  Boston Celtics
# Number               0.0            30.0             8.0             NaN
# Position              PG              SG              PF              PF
# Age                 25.0            27.0            29.0            21.0
#
#                        4                5               6
# Name        Terry Rozier  Jered Sullinger     Evan Turner
# Team      Boston Celtics   Boston Celtics  Boston Celtics
# Number              12.0              7.0            11.0
# Position              PG                C              SG
# Age                 22.0              NaN            27.0

# %%
data.describe()
# Out:
#                  Name            Team  Number Position   Age
# count               7               7     7.0        7   7.0
# unique              7               1     7.0        4   6.0
# top     Avery Bradley  Boston Celtics     0.0       PG  27.0
# freq                1               7     1.0        2   2.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      7 non-null      object
#  1   Team      7 non-null      object
#  2   Number    7 non-null      object
#  3   Position  7 non-null      object
#  4   Age       7 non-null      object
# dtypes: object(5)
# memory usage: 408.0+ bytes

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
nan = data == 'NaN'
nan
# Out:
#     Name   Team  Number  Position    Age
# 0  False  False   False     False  False
# 1  False  False   False     False  False
# 2  False  False   False     False  False
# 3  False  False    True     False  False
# 4  False  False   False     False  False
# 5  False  False   False     False   True
# 6  False  False   False     False  False

# %%
data.Number.iloc[3] = float(15)
data.Age.iloc[5] = float(20)

# %%
print('First:\n', df.Number)
print('\n\n\nSecond:\n', data.Number)
# Out:
# First:
#  0     0.0
# 1    30.0
# 2     8.0
# 3     NaN
# 4    12.0
# 5     7.0
# 6    11.0
# Name: Number, dtype: object
#
#
#
# Second:
#  0     0.0
# 1    30.0
# 2     8.0
# 3    15.0
# 4    12.0
# 5     7.0
# 6    11.0
# Name: Number, dtype: object

# %%
data.min()
# Out:
# Name         Avery Bradley
# Team        Boston Celtics
# Number                 0.0
# Position                 C
# Age                   20.0
# dtype: object

# %%
data.max()
# Out:
# Name          Terry Rozier
# Team        Boston Celtics
# Number                30.0
# Position                SG
# Age                   29.0
# dtype: object

# %%
data
# Out:
#               Name            Team Number Position   Age
# 0    Avery Bradley  Boston Celtics    0.0       PG  25.0
# 1     John Holland  Boston Celtics   30.0       SG  27.0
# 2    Jonas Jerebko  Boston Celtics    8.0       PF  29.0
# 3    Jordan Mickey  Boston Celtics   15.0       PF  21.0
# 4     Terry Rozier  Boston Celtics   12.0       PG  22.0
# 5  Jered Sullinger  Boston Celtics    7.0        C  20.0
# 6      Evan Turner  Boston Celtics   11.0       SG  27.0

# %%
lst = []
for i in range(4+1):
  lst.append(data.iat[i, i])

data == lst
# Out:
#     Name  Team  Number  Position    Age
# 0   True  True   False     False  False
# 1  False  True   False     False  False
# 2  False  True    True      True  False
# 3  False  True   False      True  False
# 4  False  True   False     False   True
# 5  False  True   False     False  False
# 6  False  True   False     False  False

# %%
data
# Out:
#               Name            Team Number Position   Age
# 0    Avery Bradley  Boston Celtics    0.0       PG  25.0
# 1     John Holland  Boston Celtics   30.0       SG  27.0
# 2    Jonas Jerebko  Boston Celtics    8.0       PF  29.0
# 3    Jordan Mickey  Boston Celtics    NaN       PF  21.0
# 4     Terry Rozier  Boston Celtics   12.0       PG  22.0
# 5  Jered Sullinger  Boston Celtics    7.0        C   NaN
# 6      Evan Turner  Boston Celtics   11.0       SG  27.0

# %%
data.to_csv('Abdulhay_code.csv')

# %% [markdown]
# # **Pandas exercice**

# %%
# !wget 'Abdulhay_code.csv'
# Out:
# --2023-03-03 08:23:18--  http://abdulhay_code.csv/
# Resolving abdulhay_code.csv (abdulhay_code.csv)... failed: Name or service not known.
# wget: unable to resolve host address ‘abdulhay_code.csv’

# %%
url = 'Abdulhay_code.csv'
def load_data():
  data = pd.read_csv(url)
  return data

data = load_data()

# %%
data
# Out:
#    Unnamed: 0             Name            Team  Number Position   Age
# 0           0    Avery Bradley  Boston Celtics     0.0       PG  25.0
# 1           1     John Holland  Boston Celtics    30.0       SG  27.0
# 2           2    Jonas Jerebko  Boston Celtics     8.0       PF  29.0
# 3           3    Jordan Mickey  Boston Celtics     NaN       PF  21.0
# 4           4     Terry Rozier  Boston Celtics    12.0       PG  22.0
# 5           5  Jered Sullinger  Boston Celtics     7.0        C   NaN
# 6           6      Evan Turner  Boston Celtics    11.0       SG  27.0

# %%
import matplotlib.pyplot as plt

data.hist(color='indigo')
plt.show()

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(data)
plt.show()

# %%
data.plot.bar()
plt.show()

# %%
data.plot.barh()
plt.show()

# %%
data.plot.scatter(x='Age', y='Number', color='indigo')
plt.show()

# %%
data.plot.pie(y='Age', subplots=True)
plt.show()

# %%
data.plot.area()
plt.show()

# %%
data.plot.box()
plt.show()

# %%
data.plot.density()
plt.show()

# %%
data.plot.hexbin(x='Age', y='Number')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
import numpy as np

X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
y = np.dot(X, np.array([1, 2])) + 3

model = LinearRegression()

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state = 20)

model.fit(x_train,y_train)

model.coef_
# Out:
# array([1., 2.])

# %%
model.intercept_
# Out:
# 3.0000000000000027

# %%
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import mean_absolute_error as MAE

MSE(data.Number, data.Age)
# Out:
# 233.71428571428572

# %%
MAE(data.Number, data.Age)
# Out:
# 13.428571428571429

# %%
df
# Out:
#               Name            Team Number Position   Age
# 0    Avery Bradley  Boston Celtics    0.0       PG  25.0
# 1     John Holland  Boston Celtics   30.0       SG  27.0
# 2    Jonas Jerebko  Boston Celtics    8.0       PF  29.0
# 3    Jordan Mickey  Boston Celtics    NaN       PF  21.0
# 4     Terry Rozier  Boston Celtics   12.0       PG  22.0
# 5  Jered Sullinger  Boston Celtics    7.0        C   NaN
# 6      Evan Turner  Boston Celtics   11.0       SG  27.0

# %%
data
# Out:
#               Name            Team Number Position   Age
# 0    Avery Bradley  Boston Celtics    0.0       PG  25.0
# 1     John Holland  Boston Celtics   30.0       SG  27.0
# 2    Jonas Jerebko  Boston Celtics    8.0       PF  29.0
# 3    Jordan Mickey  Boston Celtics   15.0       PF  21.0
# 4     Terry Rozier  Boston Celtics   12.0       PG  22.0
# 5  Jered Sullinger  Boston Celtics    7.0        C  20.0
# 6      Evan Turner  Boston Celtics   11.0       SG  27.0

# %%
data[df == data]
# Out:
#               Name            Team Number Position   Age
# 0    Avery Bradley  Boston Celtics    0.0       PG  25.0
# 1     John Holland  Boston Celtics   30.0       SG  27.0
# 2    Jonas Jerebko  Boston Celtics    8.0       PF  29.0
# 3    Jordan Mickey  Boston Celtics    NaN       PF  21.0
# 4     Terry Rozier  Boston Celtics   12.0       PG  22.0
# 5  Jered Sullinger  Boston Celtics    7.0        C   NaN
# 6      Evan Turner  Boston Celtics   11.0       SG  27.0

# %%
data[df != data]
# Out:
#   Name Team Number Position   Age
# 0  NaN  NaN    NaN      NaN   NaN
# 1  NaN  NaN    NaN      NaN   NaN
# 2  NaN  NaN    NaN      NaN   NaN
# 3  NaN  NaN   15.0      NaN   NaN
# 4  NaN  NaN    NaN      NaN   NaN
# 5  NaN  NaN    NaN      NaN  20.0
# 6  NaN  NaN    NaN      NaN   NaN
